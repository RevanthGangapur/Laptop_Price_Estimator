# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe9 in position 131543: invalid continuation byte
# When above error is encountered, we will use encoding option in the read_csn and set it to latin

# %%
df=pd.read_csv("D:/1kpsD9/Project/Laptop Price/laptop_price.csv",encoding='latin')
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# 1              Ultrabook    13.3                                    1440x900
# 2               Notebook    15.6                           Full HD 1920x1080
# 3              Ultrabook    15.4          IPS Panel Retina Display 2880x1800
# 4              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...                  ...     ...                                         ...
# 1298  2 in 1 Convertible    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  2 in 1 Convertible    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300            Notebook    14.0                                    1366x768
# 1301            Notebook    15.6                                    1366x768
# 1302            Notebook    15.6                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00
# 3               AMD Radeon Pro 455       macOS  1.83kg      2537.45
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg       638.00
# 1299         Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1300             Intel HD Graphics  Windows 10   1.5kg       229.00
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1302             Intel HD Graphics  Windows 10   2.2kg       369.00
#
# [1303 rows x 13 columns]

# %%
df.drop(columns=['laptop_ID'],inplace=True)

# %%
df.sample()
# Out:
#    Company             Product  TypeName  Inches   ScreenResolution  \
# 76  Lenovo  IdeaPad 320-15IKBN  Notebook    15.6  Full HD 1920x1080
#
#                            Cpu  Ram   Memory                    Gpu  OpSys  \
# 76  Intel Core i5 7200U 2.5GHz  8GB  2TB HDD  Intel HD Graphics 620  No OS
#
#    Weight  Price_euros
# 76  2.2kg        519.0

# %%
df.duplicated().sum()
# Out:
# 28

# %%
df[df.duplicated()]
# Out:
#      Company                                    Product            TypeName  \
# 1275    Asus                       ZenBook UX305CA-UBM1           Ultrabook
# 1276    Dell                              Inspiron 3567            Notebook
# 1277    Acer                             Aspire ES1-531            Notebook
# 1278    Dell                              Inspiron 3552            Notebook
# 1279  Lenovo                         IdeaPad Y700-15ISK            Notebook
# 1280      HP                        Pavilion 15-AW003nv            Notebook
# 1281    Dell                              Inspiron 3567            Notebook
# 1282      HP                           Stream 11-Y000na             Netbook
# 1283    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce            Notebook
# 1284  Lenovo                             Yoga 500-14ISK  2 in 1 Convertible
# 1285  Lenovo                             Yoga 900-13ISK  2 in 1 Convertible
# 1286  Lenovo                         IdeaPad 100S-14IBR            Notebook
# 1287      HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1288    Asus        X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
# 1289    Asus                       ZenBook UX305CA-UBM1           Ultrabook
# 1290    Dell                              Inspiron 3567            Notebook
# 1291    Acer                             Aspire ES1-531            Notebook
# 1292    Dell                              Inspiron 3552            Notebook
# 1293  Lenovo                         IdeaPad Y700-15ISK            Notebook
# 1294      HP                        Pavilion 15-AW003nv            Notebook
# 1295    Dell                              Inspiron 3567            Notebook
# 1296      HP                           Stream 11-Y000na             Netbook
# 1297    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce            Notebook
# 1298  Lenovo                             Yoga 500-14ISK  2 in 1 Convertible
# 1299  Lenovo                             Yoga 900-13ISK  2 in 1 Convertible
# 1300  Lenovo                         IdeaPad 100S-14IBR            Notebook
# 1301      HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1302    Asus        X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#       Inches                            ScreenResolution  \
# 1275    13.3                 IPS Panel Full HD 1920x1080
# 1276    15.6                                    1366x768
# 1277    15.6                                    1366x768
# 1278    15.6                                    1366x768
# 1279    15.6                 IPS Panel Full HD 1920x1080
# 1280    15.6                           Full HD 1920x1080
# 1281    15.6                                    1366x768
# 1282    11.6                                    1366x768
# 1283    15.6                                    1366x768
# 1284    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1285    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1286    14.0                                    1366x768
# 1287    15.6                                    1366x768
# 1288    15.6                                    1366x768
# 1289    13.3                 IPS Panel Full HD 1920x1080
# 1290    15.6                                    1366x768
# 1291    15.6                                    1366x768
# 1292    15.6                                    1366x768
# 1293    15.6                 IPS Panel Full HD 1920x1080
# 1294    15.6                           Full HD 1920x1080
# 1295    15.6                                    1366x768
# 1296    11.6                                    1366x768
# 1297    15.6                                    1366x768
# 1298    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300    14.0                                    1366x768
# 1301    15.6                                    1366x768
# 1302    15.6                                    1366x768
#
#                                        Cpu   Ram              Memory  \
# 1275              Intel Core M 6Y30 0.9GHz   8GB           512GB SSD
# 1276            Intel Core i3 7100U 2.4GHz   6GB             1TB HDD
# 1277  Intel Celeron Dual Core N3060 1.6GHz   4GB           500GB HDD
# 1278  Intel Celeron Dual Core N3050 1.6GHz   2GB           500GB HDD
# 1279           Intel Core i7 6700HQ 2.6GHz   8GB             1TB HDD
# 1280             AMD A9-Series 9410 2.9GHz   6GB        1.0TB Hybrid
# 1281            Intel Core i7 7500U 2.7GHz   8GB             1TB HDD
# 1282  Intel Celeron Dual Core N3060 1.6GHz   2GB  32GB Flash Storage
# 1283            Intel Core i7 6500U 2.5GHz   4GB           500GB HDD
# 1284            Intel Core i7 6500U 2.5GHz   4GB           128GB SSD
# 1285            Intel Core i7 6500U 2.5GHz  16GB           512GB SSD
# 1286  Intel Celeron Dual Core N3050 1.6GHz   2GB  64GB Flash Storage
# 1287            Intel Core i7 6500U 2.5GHz   6GB             1TB HDD
# 1288  Intel Celeron Dual Core N3050 1.6GHz   4GB           500GB HDD
# 1289              Intel Core M 6Y30 0.9GHz   8GB           512GB SSD
# 1290            Intel Core i3 7100U 2.4GHz   6GB             1TB HDD
# 1291  Intel Celeron Dual Core N3060 1.6GHz   4GB           500GB HDD
# 1292  Intel Celeron Dual Core N3050 1.6GHz   2GB           500GB HDD
# 1293           Intel Core i7 6700HQ 2.6GHz   8GB             1TB HDD
# 1294             AMD A9-Series 9410 2.9GHz   6GB        1.0TB Hybrid
# 1295            Intel Core i7 7500U 2.7GHz   8GB             1TB HDD
# 1296  Intel Celeron Dual Core N3060 1.6GHz   2GB  32GB Flash Storage
# 1297            Intel Core i7 6500U 2.5GHz   4GB           500GB HDD
# 1298            Intel Core i7 6500U 2.5GHz   4GB           128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB           512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB  64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB             1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB           500GB HDD
#
#                           Gpu       OpSys  Weight  Price_euros
# 1275    Intel HD Graphics 515  Windows 10   1.2kg       729.00
# 1276    Intel HD Graphics 620  Windows 10   2.3kg       459.00
# 1277    Intel HD Graphics 400       Linux   2.4kg       289.00
# 1278        Intel HD Graphics  Windows 10  2.20kg       379.00
# 1279  Nvidia GeForce GTX 960M  Windows 10   2.6kg       899.00
# 1280       AMD Radeon R7 M440  Windows 10  2.04kg       549.99
# 1281       AMD Radeon R5 M430       Linux   2.3kg       805.99
# 1282    Intel HD Graphics 400  Windows 10  1.17kg       209.00
# 1283      Nvidia GeForce 920M  Windows 10   2.2kg       720.32
# 1284    Intel HD Graphics 520  Windows 10   1.8kg       638.00
# 1285    Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1286        Intel HD Graphics  Windows 10   1.5kg       229.00
# 1287       AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1288        Intel HD Graphics  Windows 10   2.2kg       369.00
# 1289    Intel HD Graphics 515  Windows 10   1.2kg       729.00
# 1290    Intel HD Graphics 620  Windows 10   2.3kg       459.00
# 1291    Intel HD Graphics 400       Linux   2.4kg       289.00
# 1292        Intel HD Graphics  Windows 10  2.20kg       379.00
# 1293  Nvidia GeForce GTX 960M  Windows 10   2.6kg       899.00
# 1294       AMD Radeon R7 M440  Windows 10  2.04kg       549.99
# 1295       AMD Radeon R5 M430       Linux   2.3kg       805.99
# 1296    Intel HD Graphics 400  Windows 10  1.17kg       209.00
# 1297      Nvidia GeForce 920M  Windows 10   2.2kg       720.32
# 1298    Intel HD Graphics 520  Windows 10   1.8kg       638.00
# 1299    Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1300        Intel HD Graphics  Windows 10   1.5kg       229.00
# 1301       AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1302        Intel HD Graphics  Windows 10   2.2kg       369.00

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (1275, 12)

# %%
df['Price']=round(df['Price_euros']*96.28).astype('int')
df.drop(columns=['Price_euros'],inplace=True)

# %%
df.sample()
# Out:
#      Company            Product TypeName  Inches             ScreenResolution  \
# 1197    Asus  Rog G752VY-GC229T   Gaming    17.3  IPS Panel Full HD 1920x1080
#
#                               Cpu   Ram                Memory  \
# 1197  Intel Core i7 6700HQ 2.6GHz  16GB  512GB SSD +  1TB HDD
#
#                           Gpu       OpSys Weight   Price
# 1197  Nvidia GeForce GTX 980M  Windows 10  4.3kg  207002

# %%
df.isnull().sum()
# Out:
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
# EDA
# - Univariate Anaylsis
# - Multi-variate Analysis

# %%
# Company Column
df['Company'].value_counts()
# Out:
# Company
# Dell         291
# Lenovo       289
# HP           268
# Asus         152
# Acer         101
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
9+7+7+6+4+4+3+3+3+3+2
# Out:
# 51

# %%
df['Company'].value_counts().plot(kind='bar')
plt.show()

# %%
sns.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df=df[df.groupby('Company').Company.transform('count')>10].copy()

# %%
df.shape
# Out:
# (1224, 12)

# %%
1275-1224
# Out:
# 51

# %%
df['Company'].value_counts()
# Out:
# Company
# Dell       291
# Lenovo     289
# HP         268
# Asus       152
# Acer       101
# MSI         54
# Toshiba     48
# Apple       21
# Name: count, dtype: int64

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
sns.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df['Product'].value_counts()
# Out:
# Product
# XPS 13                                 30
# Inspiron 3567                          25
# 250 G6                                 21
# Legion Y520-15IKBN                     19
# Vostro 3568                            19
#                                        ..
# Ideapad 520-15IKBR                      1
# Thinkpad X260                           1
# Rog G752VL-UH71T                        1
# Portege X30-D-10L                       1
# X553SA-XX031T (N3050/4GB/500GB/W10)     1
# Name: count, Length: 589, dtype: int64

# %%
df.drop(columns=['Product'],inplace=True)

# %%
df.sample()
# Out:
#     Company            TypeName  Inches                 ScreenResolution  \
# 880      HP  2 in 1 Convertible    13.3  Full HD / Touchscreen 1920x1080
#
#                             Cpu  Ram     Memory                    Gpu  \
# 880  Intel Core i5 7200U 2.5GHz  4GB  256GB SSD  Intel HD Graphics 620
#
#           OpSys  Weight   Price
# 880  Windows 10  1.28kg  163676

# %%
df['TypeName'].value_counts()
# Out:
# TypeName
# Notebook              688
# Gaming                200
# Ultrabook             171
# 2 in 1 Convertible    114
# Workstation            29
# Netbook                22
# Name: count, dtype: int64

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TypeName'>

# %%
sns.barplot(x=df['TypeName'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df['Inches'].value_counts()
# Out:
# Inches
# 15.6    637
# 14.0    182
# 17.3    162
# 13.3    152
# 12.5     37
# 11.6     29
# 12.0      6
# 13.9      6
# 15.4      4
# 10.1      4
# 18.4      1
# 17.0      1
# 14.1      1
# 11.3      1
# 15.0      1
# Name: count, dtype: int64

# %%
df['Inches'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Inches'>

# %%
sns.displot(x=df['Inches'],kde=True)

# %%
sns.barplot(x=df['Inches'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                492
# 1366x768                                         258
# IPS Panel Full HD 1920x1080                      217
# IPS Panel Full HD / Touchscreen 1920x1080         48
# Full HD / Touchscreen 1920x1080                   45
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     10
# 4K Ultra HD / Touchscreen 3840x2160                8
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Touchscreen 1920x1200                    4
# 1440x900                                           4
# IPS Panel Retina Display 2880x1800                 4
# IPS Panel 2560x1440                                4
# IPS Panel Quad HD+ / Touchscreen 3200x1800         4
# IPS Panel Touchscreen 1366x768                     3
# IPS Panel Quad HD+ 2560x1440                       3
# 2560x1440                                          3
# Quad HD+ 3200x1800                                 3
# IPS Panel Quad HD+ 3200x1800                       2
# 1920x1080                                          2
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# IPS Panel Full HD 2560x1440                        1
# IPS Panel Full HD 1366x768                         1
# Touchscreen / Quad HD+ 3200x1800                   1
# Touchscreen / Full HD 1920x1080                    1
# Name: count, dtype: int64

# %%
a="IPS Panel Touchscreen / 4K Ultra HD 3840x2160"

# %%
a.split()
# Out:
# ['IPS', 'Panel', 'Touchscreen', '/', '4K', 'Ultra', 'HD', '3840x2160']

# %%
a.split()[-1]
# Out:
# '3840x2160'

# %%
a.split()[-1].split("x")
# Out:
# ['3840', '2160']

# %%
a.split()[-1].split('x')[0]
# Out:
# '3840'

# %%
a.split()[-1].split('x')[1]
# Out:
# '2160'

# %%
(lambda b:b.split()[-1].split('x')[0])("Touchscreen / Full HD 1920x1080 ")
# Out:
# '1920'

# %%
df['X_res']=df['ScreenResolution'].apply(lambda b:b.split()[-1].split('x')[0]).astype('int')
df['Y_res']=df['ScreenResolution'].apply(lambda b:b.split()[-1].split('x')[1]).astype('int')

# %%
df['Touchscreen']=df['ScreenResolution'].apply(lambda x:1 if "Touchscreen" in x else 0)
df['IPS']=df['ScreenResolution'].apply(lambda x:1 if "IPS" in x else 0)

# %%
df.sample(3)
# Out:
#     Company   TypeName  Inches   ScreenResolution                         Cpu  \
# 39       HP   Notebook    15.6  Full HD 1920x1080  Intel Core i5 8250U 1.6GHz
# 208    Dell  Ultrabook    13.3  Full HD 1920x1080  Intel Core i7 8550U 1.8GHz
# 784  Lenovo  Ultrabook    14.0  Full HD 1920x1080  Intel Core i7 7500U 2.7GHz
#
#       Ram     Memory                     Gpu       OpSys Weight   Price  \
# 39    8GB  256GB SSD   Nvidia GeForce 930MX   Windows 10  2.1kg   84630
# 208   8GB  256GB SSD  Intel UHD Graphics 620  Windows 10  1.2kg  139510
# 784  16GB  512GB SSD   Intel HD Graphics 620  Windows 10  1.7kg  221348
#
#      X_res  Y_res  Touchscreen  IPS
# 39    1920   1080            0    0
# 208   1920   1080            0    0
# 784   1920   1080            0    0

# %%
df.drop(columns="ScreenResolution",inplace=True)

# %%
df.sample()
# Out:
#      Company  TypeName  Inches                       Cpu  Ram   Memory  \
# 1167  Lenovo  Notebook    15.6  Intel Core i3 6006U 2GHz  4GB  1TB HDD
#
#                         Gpu       OpSys Weight  Price  X_res  Y_res  \
# 1167  Nvidia GeForce 920MX   Windows 10  2.2kg  45059   1920   1080
#
#       Touchscreen  IPS
# 1167            0    0

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz     183
# Intel Core i7 7700HQ 2.8GHz    142
# Intel Core i7 7500U 2.7GHz     124
# Intel Core i7 8550U 1.8GHz      71
# Intel Core i5 8250U 1.6GHz      71
#                               ...
# AMD E-Series E2-9000 2.2GHz      1
# Intel Core M M3-6Y30 0.9GHz      1
# Intel Core i5 2.9GHz             1
# Intel Atom x5-Z8350 1.44GHz      1
# AMD A9-Series 9410 2.9GHz        1
# Name: count, Length: 111, dtype: int64

# %%
a="Intel Core i7 7700HQ 2.8GHz"

# %%
a.split()
# Out:
# ['Intel', 'Core', 'i7', '7700HQ', '2.8GHz']

# %%
a.split()[0:3]
# Out:
# ['Intel', 'Core', 'i7']

# %%
" ".join(a.split()[0:3])
# Out:
# 'Intel Core i7'

# %%
(lambda a:" ".join(a.split()[0:3]))("Intel Core i7 7700HQ 2.8GHz")
# Out:
# 'Intel Core i7'

# %%
df['Cpu']=df['Cpu'].apply(lambda a:" ".join(a.split()[0:3]))

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i7               493
# Intel Core i5               411
# Intel Core i3               134
# Intel Celeron Dual           66
# Intel Pentium Quad           27
# Intel Core M                 16
# AMD A9-Series 9420           12
# AMD A6-Series 9220            8
# AMD A12-Series 9720P          7
# Intel Celeron Quad            5
# Intel Atom x5-Z8550           4
# AMD A8-Series 7410            4
# Intel Pentium Dual            3
# AMD Ryzen 1700                3
# AMD A9-Series A9-9420         2
# AMD A10-Series 9600P          2
# Intel Xeon E3-1535M           2
# AMD E-Series 7110             2
# AMD A10-Series 9620P          2
# AMD A6-Series A6-9220         2
# AMD A10-Series A10-9620P      2
# Intel Xeon E3-1505M           2
# AMD E-Series E2-9000e         2
# AMD E-Series 9000e            1
# AMD Ryzen 1600                1
# AMD E-Series 6110             1
# AMD FX 9830P                  1
# AMD E-Series E2-6110          1
# AMD E-Series E2-9000          1
# AMD A6-Series 7310            1
# Intel Atom x5-Z8350           1
# AMD A12-Series 9700P          1
# AMD A4-Series 7210            1
# AMD FX 8800P                  1
# AMD E-Series 9000             1
# AMD A9-Series 9410            1
# Name: count, dtype: int64

# %%
def fetch_processor_name(text):
  if text=="Intel Core i7" or text=="Intel Core i5" or text=="Intel Core i3" or text=="Intel Core M":
    return text
  elif text.split()[0]=="Intel":
    return " ".join(text.split()[0:2])
  else:
    return "AMD Processor"

# %%
df['Cpu']=df['Cpu'].apply(fetch_processor_name)

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i7    493
# Intel Core i5    411
# Intel Core i3    134
# Intel Celeron     71
# AMD Processor     60
# Intel Pentium     30
# Intel Core M      16
# Intel Atom         5
# Intel Xeon         4
# Name: count, dtype: int64

# %%
df['Cpu'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cpu'>

# %%
sns.barplot(x=df['Cpu'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df['Ram']
# Out:
# 0        8GB
# 1        8GB
# 2        8GB
# 3       16GB
# 4        8GB
#         ...
# 1270     4GB
# 1271    16GB
# 1272     2GB
# 1273     6GB
# 1274     4GB
# Name: Ram, Length: 1224, dtype: object

# %%
df['Ram']=df['Ram'].apply(lambda x:x.replace("GB","")).astype('int')

# %%
df['Ram'].value_counts()
# Out:
# Ram
# 8     595
# 4     351
# 16    186
# 6      34
# 12     25
# 32     15
# 2      14
# 24      3
# 64      1
# Name: count, dtype: int64

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Ram'>

# %%
sns.barplot(x=df['Ram'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        393
# 1TB HDD                          214
# 500GB HDD                        124
# 512GB SSD                        105
# 128GB SSD +  1TB HDD              93
# 256GB SSD +  1TB HDD              73
# 128GB SSD                         71
# 32GB Flash Storage                29
# 2TB HDD                           16
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           12
# 64GB Flash Storage                10
# 256GB SSD +  2TB HDD              10
# 256GB Flash Storage                8
# 1.0TB Hybrid                       7
# 16GB Flash Storage                 6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 32GB SSD                           2
# 256GB SSD +  256GB SSD             2
# 512GB SSD +  512GB SSD             1
# 512GB SSD +  256GB SSD             1
# 64GB Flash Storage +  1TB HDD      1
# 64GB SSD                           1
# 1TB HDD +  1TB HDD                 1
# 128GB HDD                          1
# 240GB SSD                          1
# 8GB SSD                            1
# 508GB Hybrid                       1
# 1.0TB HDD                          1
# 512GB SSD +  1.0TB Hybrid          1
# 256GB SSD +  1.0TB Hybrid          1
# Name: count, dtype: int64

# %%
# df['Memory']=df['Memory'].astype(str).replace('\.0','',regex=True)
# df['Memory']=df['Memory'].str.replace('GB','')
# df['Memory']=df['Memory'].str.replace('TB','000')

# new=df['Memory'].str.split("+",n=1,expand=True)
# df['first']=new[0]
# df['first']=df['first'].str.strip()
# df['second']=new[1]

# df['Layer1HDD']=df['first'].apply(lambda x:1 if 'HDD' in x else 0)
# df['Layer1SSD']=df['first'].apply(lambda x:1 if 'SSD' in x else 0)
# df['Layer1Hybrid']=df['first'].apply(lambda x:1 if 'Hybrid' in x else 0)
# df['Layer1Flash_Storage']=df['first'].apply(lambda x:1 if 'Flash Storage' in x else 0)

# df['first']=df['first'].str.replace(r'\D','',regex=True)

# df['second'].fillna("0",inplace=True)

# df['Layer2HDD']=df['second'].apply(lambda x:1 if 'HDD' in x else 0)
# df['Layer2SSD']=df['second'].apply(lambda x:1 if 'SSD' in x else 0)
# df['Layer2Hybrid']=df['second'].apply(lambda x:1 if 'Hybrid' in x else 0)
# df['Layer2Flash_Storage']=df['second'].apply(lambda x:1 if 'Flash Storage' in x else 0)

# df['second']=df['second'].str.replace(r'\D','',regex=True)

# df['first']=df['first'].astype('int')
# df['second']=df['second'].astype('int')

# df['HDD']=df['first']*df['Layer1HDD']+df['second']*df['Layer2HDD']
# df['SSD']=df['first']*df['Layer1SSD']+df['second']*df['Layer2SSD']
# df['Hybrid']=df['first']*df['Layer1Hybrid']+df['second']*df['Layer2Hybrid']
# df['Flash_Storage']=df['first']*df['Layer1Flash_Storage']+df['second']*df['Layer2Flash_Storage']

# df.drop(columns=['first','second','Layer1HDD','Layer1SSD','Layer1Hybrid','Layer1Flash_Storage',
#                  'Layer2HDD','Layer2SSD','Layer2Hybrid','Layer2Flash_Storage'],inplace=True)

# %%
# Due to complexity in handling different types of storage options, we will skip this
df.drop(columns=['Memory'],inplace=True)

# %%
df.sample()
# Out:
#     Company  TypeName  Inches            Cpu  Ram                     Gpu  \
# 223      HP  Notebook    15.6  Intel Core i5    8  Intel UHD Graphics 620
#
#           OpSys Weight  Price  X_res  Y_res  Touchscreen  IPS
# 223  Windows 10  2.1kg  76446   1920   1080            0    0

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      265
# Intel HD Graphics 520      179
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     65
# Nvidia GeForce GTX 1060     45
#                           ...
# Intel Graphics 620           1
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# Nvidia GeForce 960M          1
# Name: count, Length: 108, dtype: int64

# %%
df['Gpu']=df['Gpu'].apply(lambda x:x.split()[0])

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel     666
# Nvidia    385
# AMD       173
# Name: count, dtype: int64

# %%
df['Gpu'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Gpu'>

# %%
sns.barplot(x=df['Gpu'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1011
# No OS             63
# Linux             58
# Windows 7         45
# Chrome OS         22
# macOS             13
# Mac OS X           8
# Android            2
# Windows 10 S       2
# Name: count, dtype: int64

# %%
def fetch_os(text):
  if text=="Windows 10" or text=="Windows 10 S":
    return "Windows 10"
  elif text=="Windows 7":
    return text
  elif text=="Mac OS X" or text=="macOS":
    return "Mac OS"
  else:
    return "Linux/No OS/Others"

# %%
df['OpSys']=df['OpSys'].apply(fetch_os)

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10            1013
# Linux/No OS/Others     145
# Windows 7               45
# Mac OS                  21
# Name: count, dtype: int64

# %%
df['OpSys'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='OpSys'>

# %%
sns.barplot(x=df['OpSys'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df['Weight']=df['Weight'].apply(lambda x:x.replace("kg","")).astype('float')

# %%
sns.displot(x=df['Weight'],kde=True)

# %%
sns.scatterplot(x=df['Weight'],y=df['Price'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
df.sample()
# Out:
#      Company  TypeName  Inches            Cpu  Ram    Gpu       OpSys  Weight  \
# 1175    Asus  Notebook    14.0  Intel Core i3    4  Intel  Windows 10     2.0
#
#       Price  X_res  Y_res  Touchscreen  IPS
# 1175  74039   1920   1080            0    0

# %%
df['Touchscreen'].value_counts()
# Out:
# Touchscreen
# 0    1055
# 1     169
# Name: count, dtype: int64

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Touchscreen'>

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df['IPS'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='IPS'>

# %%
sns.barplot(x=df['IPS'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Inches         0.055330
# Ram            0.726639
# Weight         0.212038
# Price          1.000000
# X_res          0.553707
# Y_res          0.552964
# Touchscreen    0.161443
# IPS            0.289225
# Name: Price, dtype: float64

# %%
# PPI/pixel density: Pixels Per Inch

# %%
df['ppi']=round(((df['X_res']**2)+(df['Y_res']**2))**0.5/df['Inches']).astype(int)

# %%
df['ppi']
# Out:
# 0       227
# 1       128
# 2       141
# 3       221
# 4       227
#        ...
# 1270    157
# 1271    276
# 1272    112
# 1273    100
# 1274    100
# Name: ppi, Length: 1224, dtype: int32

# %%
sns.displot(x=df['ppi'],kde=True)

# %%
sns.scatterplot(x=df['ppi'],y=df['Price'])
# Out:
# <Axes: xlabel='ppi', ylabel='Price'>

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Inches         0.055330
# Ram            0.726639
# Weight         0.212038
# Price          1.000000
# X_res          0.553707
# Y_res          0.552964
# Touchscreen    0.161443
# IPS            0.289225
# ppi            0.483821
# Name: Price, dtype: float64

# %%
df.drop(columns=['Inches','X_res','Y_res'],inplace=True)

# %%
df.sample()
# Out:
#     Company  TypeName            Cpu  Ram     Gpu               OpSys  Weight  \
# 122  Lenovo  Notebook  Intel Core i5    8  Nvidia  Linux/No OS/Others     2.2
#
#      Price  Touchscreen  IPS  ppi
# 122  60560            0    0  141

# %%
df.shape
# Out:
# (1224, 11)

# %%
sns.displot(x=df['Price'],kde=True)
plt.show()

# %%
sns.displot(x=np.log(df['Price']),kde=True)
plt.show()

# %%
X=df.drop(columns=['Price'])
y=np.log(df['Price'])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.15,random_state=42)

# %%
X.shape
# Out:
# (1224, 10)

# %%
X_train.shape
# Out:
# (1040, 10)

# %%
X_test.shape
# Out:
# (184, 10)

# %%
1224*0.85
# Out:
# 1040.3999999999999

# %%
X
# Out:
#      Company            TypeName            Cpu  Ram    Gpu  \
# 0      Apple           Ultrabook  Intel Core i5    8  Intel
# 1      Apple           Ultrabook  Intel Core i5    8  Intel
# 2         HP            Notebook  Intel Core i5    8  Intel
# 3      Apple           Ultrabook  Intel Core i7   16    AMD
# 4      Apple           Ultrabook  Intel Core i5    8  Intel
# ...      ...                 ...            ...  ...    ...
# 1270  Lenovo  2 in 1 Convertible  Intel Core i7    4  Intel
# 1271  Lenovo  2 in 1 Convertible  Intel Core i7   16  Intel
# 1272  Lenovo            Notebook  Intel Celeron    2  Intel
# 1273      HP            Notebook  Intel Core i7    6    AMD
# 1274    Asus            Notebook  Intel Celeron    4  Intel
#
#                    OpSys  Weight  Touchscreen  IPS  ppi
# 0                 Mac OS    1.37            0    1  227
# 1                 Mac OS    1.34            0    0  128
# 2     Linux/No OS/Others    1.86            0    0  141
# 3                 Mac OS    1.83            0    1  221
# 4                 Mac OS    1.37            0    1  227
# ...                  ...     ...          ...  ...  ...
# 1270          Windows 10    1.80            1    1  157
# 1271          Windows 10    1.30            1    1  276
# 1272          Windows 10    1.50            0    0  112
# 1273          Windows 10    2.19            0    0  100
# 1274          Windows 10    2.20            0    0  100
#
# [1224 rows x 10 columns]

# %%
X_train
# Out:
#      Company            TypeName            Cpu  Ram     Gpu  \
# 249    Apple           Ultrabook  Intel Core i5    8   Intel
# 453   Lenovo            Notebook  Intel Core i5    8   Intel
# 200     Dell              Gaming  Intel Core i7   16  Nvidia
# 227     Asus            Notebook  Intel Core i5    8  Nvidia
# 189     Dell            Notebook  Intel Core i7    8     AMD
# ...      ...                 ...            ...  ...     ...
# 1091      HP            Notebook  Intel Core i3    4   Intel
# 1144      HP  2 in 1 Convertible  Intel Core i7    8   Intel
# 1179      HP            Notebook  Intel Core i3    4   Intel
# 903   Lenovo           Ultrabook  Intel Core i7    8   Intel
# 1175    Asus            Notebook  Intel Core i3    4   Intel
#
#                    OpSys  Weight  Touchscreen  IPS  ppi
# 249               Mac OS    1.37            0    1  227
# 453           Windows 10    1.65            0    0  157
# 200           Windows 10    2.65            0    1  282
# 227           Windows 10    2.00            0    0  141
# 189           Windows 10    2.80            0    0  127
# ...                  ...     ...          ...  ...  ...
# 1091  Linux/No OS/Others    1.86            0    0  100
# 1144          Windows 10    1.48            1    0  221
# 1179          Windows 10    2.07            0    0  100
# 903           Windows 10    1.13            0    1  157
# 1175          Windows 10    2.00            0    0  157
#
# [1040 rows x 10 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in d:\1kpsd9\apps\anaconda\lib\site-packages (3.0.0)
# Requirement already satisfied: numpy in d:\1kpsd9\apps\anaconda\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in d:\1kpsd9\apps\anaconda\lib\site-packages (from xgboost) (1.13.1)

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor

# %%
X_train.sample()
# Out:
#      Company  TypeName            Cpu  Ram    Gpu      OpSys  Weight  \
# 1148      HP  Notebook  Intel Core i5    8  Intel  Windows 7    1.88
#
#       Touchscreen  IPS  ppi
# 1148            0    0  141

# %%
# LinearRegression
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=LinearRegression()
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)

print("R2 Score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# R2 Score: 0.7849858879655869
# MAE: 0.20009039895409467
# MSE: 0.067889727672385

# %%
# Lasso
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=Lasso(alpha=0.001)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)

print("R2 Score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# R2 Score: 0.7924908733300513
# MAE: 0.19507651616126262
# MSE: 0.06552006268733891

# %%
# Ridge
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=Ridge(alpha=10)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)

print("R2 Score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# R2 Score: 0.790310057317101
# MAE: 0.19670398718884216
# MSE: 0.06620864542184834

# %%
# KNeighborsRegressor
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=KNeighborsRegressor()
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)

print("R2 Score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# R2 Score: 0.7859688435194543
# MAE: 0.19267612707316512
# MSE: 0.06757936392818835

# %%
# DecisionTreeRegressor
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=DecisionTreeRegressor(max_depth=8)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)

print("R2 Score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# R2 Score: 0.8190516684329984
# MAE: 0.18123738074868762
# MSE: 0.05713361247139918

# %%
# Support Vector Regressor
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=SVR(C=100000)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)

print("R2 Score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# R2 Score: 0.8213243091388862
# MAE: 0.17708109415490902
# MSE: 0.056416036507849356

# %%
# AdaBoostRegressor
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=AdaBoostRegressor()
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)

print("R2 Score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# R2 Score: 0.7837195704628663
# MAE: 0.2118688336178401
# MSE: 0.06828956166278241

# %%
# RandomForestRegressor
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=RandomForestRegressor()
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)

print("R2 Score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# R2 Score: 0.8610655310040854
# MAE: 0.16047212749967324
# MSE: 0.043867926505821275

# %%
# eXtreme Gradient Boosting Regressor
# step1=ColumnTransformer(transformers=[
#     ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
#     ],remainder='passthrough')
# step2=XGBRegressor(n_estimators=50,max_depth=5)
# pipe=Pipeline([('step1',step1),('step2',step2)])
# pipe.fit(X_train,y_train)
# y_pred=pipe.predict(X_test)

# print("R2 Score:",r2_score(y_test,y_pred))
# print("MAE:",mean_absolute_error(y_test,y_pred))
# print("MSE:",mean_squared_error(y_test,y_pred))

# %%
# GradientBoostingRegressor
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=GradientBoostingRegressor(n_estimators=500)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)

print("R2 Score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# R2 Score: 0.8740620645849564
# MAE: 0.14763790925709053
# MSE: 0.03976433015513559

# %%
import pickle
pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
# !pip install streamlit --quiet

# %%
# %%writefile app.py
import streamlit as st
import pickle
import numpy as np

df=pickle.load(open('df.pkl','rb'))
pipe=pickle.load(open('pipe.pkl','rb'))

st.title("Laptop Price Predictor")
company=st.selectbox("Brand",df['Company'].unique(),index=4)
type=st.selectbox("Type",df['TypeName'].unique(),index=1)
cpu=st.selectbox("Processor",df['Cpu'].unique(),index=0)
ram=st.selectbox("RAM(in GB)",[2,4,6,8,12,16,24,32,64,128],index=3)
gpu=st.selectbox("GPU",df['Gpu'].unique(),index=0)
os=st.selectbox("Operating System",df['OpSys'].unique(),index=2)
weight=st.number_input("Weight of the laptop(in kg)",min_value=0.6,max_value=4.8,value=2.0,step=0.1)
touchscreen=st.selectbox("Touchscreen",['Yes','No'])
ips=st.selectbox("IPS",['Yes','No'])
screen_size=st.number_input("Screen Size(in Inches,calculated diagonally)",min_value=10.0,max_value=18.5,step=0.1,value=15.6)
resolution=st.selectbox("ScreenResolution",["2560x1600","1440x900","1920x1080","2880x1800",
"1366x768","2304x1440","3200x1800","1920x1200","2256x1504","3840x2160","2160x1440","2560x1440",
"1600x900","2736x1824","2400x1600"],index=2)

if st.button("PREDICT PRICE"):
  ppi=None
  if(touchscreen=='Yes'):
    touchscreen=1
  else:
    touchscreen=0
  if(ips=="Yes"):
    ips=1
  else:
    ips=0
  X_res=int(resolution.split('x')[0])
  Y_res=int(resolution.split('x')[1])
  ppi=((X_res**2)+(Y_res**2))**0.5/screen_size
  query=np.array([[company,type,cpu,ram,gpu,os,weight,touchscreen,ips,ppi]])
  op=np.exp(pipe.predict(query))
  st.subheader("The predicted price of the laptop with the above configuration is ₹"+str(round(op[0])))
# Out:
# Overwriting app.py

# %%
X_train.sample()
# Out:
#     Company  TypeName            Cpu  Ram    Gpu               OpSys  Weight  \
# 439    Asus  Notebook  Intel Core i5    4  Intel  Linux/No OS/Others     2.0
#
#      Touchscreen  IPS  ppi
# 439            0    0  141

# %%
# !streamlit run app.py --server.port 8501
# Out:
# ^C

# %%
import subprocess
import threading

def run_streamlit():
    # Launch Streamlit on port 8501 (default)
    subprocess.run(["streamlit", "run", "app.py", "--server.port", "8501"])

# Start Streamlit in a background thread
thread = threading.Thread(target=run_streamlit, daemon=True)
thread.start()

print("Streamlit is running at http://localhost:8501")
# Out:
# Streamlit is running at http://localhost:8501
